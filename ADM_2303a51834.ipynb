# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhatisaipavan/ADMB_27/blob/main/ADM_2303a51834.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import pandas as pd
s=pd.Series([12,1,5,3,2])
print(s)
# Out:
# 0    12
# 1     1
# 2     5
# 3     3
# 4     2
# dtype: int64

# %%
ds1=pd.Series([5,6,7,8,9])
ds2=pd.Series([12,4,-1,5,3])
print('sum of ds1 and ds2')
print(ds1+ds2)
print('product of ds1 and ds2')
print(ds1*ds2)
# Out:
# sum of ds1 and ds2
# 0    17
# 1    10
# 2     6
# 3    13
# 4    12
# dtype: int64
# product of ds1 and ds2
# 0    60
# 1    24
# 2    -7
# 3    40
# 4    27
# dtype: int64

# %%
import pandas as pd
from google.colab import files
mypath ='/content/banklist.csv'
data = pd.read_csv(mypath)
#print(data)
data.head()
# Out:
#                                   Bank Name          City  ST   CERT  \
# 0  Banks of Wisconsin d/b/a Bank of Kenosha       Kenosha  WI  35386
# 1                      Central Arizona Bank    Scottsdale  AZ  34527
# 2                              Sunrise Bank      Valdosta  GA  58185
# 3                     Pisgah Community Bank     Asheville  NC  58701
# 4                       Douglas County Bank  Douglasville  GA  21649
#
#    Acquiring Institution Closing Date Updated Date
# 0  North Shore Bank, FSB    31-May-13    31-May-13
# 1     Western State Bank    14-May-13    20-May-13
# 2           Synovus Bank    10-May-13    21-May-13
# 3     Capital Bank, N.A.    10-May-13    14-May-13
# 4    Hamilton State Bank    26-Apr-13    16-May-13
