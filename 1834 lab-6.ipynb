# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhatisaipavan/ADMB_27/blob/main/1834%20lab-6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D

data={
    'Feature1':[2,4,6,8,10],
    'Feature2':[1,3,5,7,9],
    'Feature3':[5,10,15,20,25]
}
df=pd.DataFrame(data)

scaler=StandardScaler()
scaled_data=scaler.fit_transform(df)

fig=plt.figure(figsize=(12,5))

ax1=fig.add_subplot(121,projection='3d')
ax1.set_xlabel("Feature1")
ax1.set_ylabel("Feature2")
ax1.set_zlabel("Feature3")
ax1.set_title("Before PCA (3D)")
ax1.legend()

ax1.scatter(df['Feature1'],df['Feature2'],df['Feature3'],color='blue',label='Original Data')

pca=PCA(n_components=2)
pca_df=pd.DataFrame(pca.fit_transform(scaled_data),columns=['PC1','PC2'])
principal_components=pca.fit_transform(scaled_data)
ax2=fig.add_subplot(122)
ax2.scatter(pca_df['PC1'],pca_df['PC2'],color='red',label="PCA Transformed Data")
ax2.set_xlabel("Principal Component 1")
ax2.set_ylabel("Principal Component 2")
ax2.set_title("After PCA (2D)")
ax2.legend()
ax2.grid()

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-17-2e84fecc5a0e>:25: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
from sklearn.datasets import load_wine

wine_data = load_wine()
df = pd.DataFrame(wine_data.data, columns=wine_data.feature_names)

scaler = StandardScaler()
scaled_data = scaler.fit_transform(df)

fig = plt.figure(figsize=(12, 5))

ax1 = fig.add_subplot(121, projection='3d')
ax1.set_xlabel("Feature 1")
ax1.set_ylabel("Feature 2")
ax1.set_zlabel("Feature 3")
ax1.set_title("Before PCA (3D)")
ax1.legend()

ax1.scatter(df['alcohol'], df['malic_acid'], df['ash'], color='blue', label='Original Data')

pca = PCA(n_components=2)
pca_df = pd.DataFrame(pca.fit_transform(scaled_data), columns=['PC1', 'PC2'])

ax2 = fig.add_subplot(122)
ax2.scatter(pca_df['PC1'], pca_df['PC2'], color='red', label="PCA Transformed Data")
ax2.set_xlabel("Principal Component 1")
ax2.set_ylabel("Principal Component 2")
ax2.set_title("After PCA (2D)")
ax2.legend()
ax2.grid()

plt.tight_layout()
plt.show()
# Out:
# <ipython-input-19-6d54ee197e32>:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax1.legend()
