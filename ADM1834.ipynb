# %% [markdown]
# <a href="https://colab.research.google.com/github/sudhatisaipavan/ADMB_27/blob/main/ADM1834.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10, 5, 7])
plt.plot( ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([2, 5, 11, 10, 15])
plt.plot( xpoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 1, 2, 3, 4, 5])
ypoints = np.array([3,8,1,10,5,7])
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 1, 2, 3, 4, 5])
ypoints = np.array([3,8,1,10,5,7])
ypoints = np.array([2,8,6,9,4,7])
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'royalblue', mfc = 'yellow')
plt.plot(ypoints, linestyle = ':')
plt.plot(ypoints, color ='r')
plt.plot(ypoints, linewidth = '20.5')
plt.plot(xpoints,ypoints,'o:b')
plt.show()
plt.plot(xpoints,ypoints,'o:b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])
plt.plot(x1, y1, x2, y2)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["a", "b", "c", "d"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()

# %%
plt.plot(x,y)
plt.title("Bar Chart Example")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.show()

# %%
plt.grid()
plt.grid(axis = 'x')
plt.grid(axis = 'y')

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.random.normal(190,20,250)
plt.hist(x)
plt.show()

# %%
y = np.array([35,25,25,15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels,explode=myexplode)
plt.show()
